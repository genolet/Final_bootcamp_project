# %%
# %cd ../
# Out:
# /Users/origenolet/Desktop/Ironhack/Week9/Final_bootcamp_project

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import functions.functions as f

# %%
data = pd.read_csv('./data/raw/hypothyroid.csv')
display(data.head())
print(data.shape)
# Out:
#   age sex on thyroxine query on thyroxine on antithyroid medication sick  \
# 0  41   F            f                  f                         f    f
# 1  23   F            f                  f                         f    f
# 2  46   M            f                  f                         f    f
# 3  70   F            t                  f                         f    f
# 4  70   F            f                  f                         f    f
#
#   pregnant thyroid surgery I131 treatment query hypothyroid  ... TT4 measured  \
# 0        f               f              f                 f  ...            t
# 1        f               f              f                 f  ...            t
# 2        f               f              f                 f  ...            t
# 3        f               f              f                 f  ...            t
# 4        f               f              f                 f  ...            t
#
# ...

# %%
data = f.data_cleaning(data)

# %%
print(data.shape)
data.head()
# Out:
# (3709, 18)
#     age sex on_thyroxine on_antithyroid_medication sick pregnant  \
# 0  41.0   F            f                         f    f        f
# 1  23.0   F            f                         f    f        f
# 2  46.0   M            f                         f    f        f
# 3  70.0   F            t                         f    f        f
# 4  70.0   F            f                         f    f        f
#
#   thyroid_surgery i131_treatment lithium goitre tumor hypopituitary   tsh  \
# 0               f              f       f      f     f             f  1.30
# 1               f              f       f      f     f             f  4.10
# 2               f              f       f      f     f             f  0.98
# 3               f              f       f      f     f             f  0.16
# 4               f              f       f      f     f             f  0.72
#
#     t3    tt4   t4u    fti binaryclass
# 0  2.5  125.0  1.14  109.0     Healthy
# ...

# %%
plt.figure(figsize=(3,3))
plt.pie(x=data["binaryclass"].value_counts(),
        labels=['Healthy','Diseased'],
        startangle = 90,
        colors=['indianred','peachpuff'],
        autopct='%.2f'
       )
plt.title("Percentage of diseased patients")
# Out:
# Text(0.5, 1.0, 'Percentage of diseased patients')

# %%
plt.figure(figsize=(3,3))
plt.pie(x=data[data["binaryclass"]=="Diseased"]["sex"].value_counts(),
        labels=['Female','Male'],
        startangle = 90,
        colors=['indianred','peachpuff'],
        autopct='%.2f'
       )
plt.title("Percentage of diseased patients")
# Out:
# Text(0.5, 1.0, 'Percentage of diseased patients')

# %%
plt.figure(figsize=(3,3))
plt.pie(x=data[data["sex"]=="F"]["binaryclass"].value_counts(),
        labels=['Healthy','Diseased'],
        startangle = 90,
        colors=['indianred','peachpuff'],
        autopct='%.2f'
       )
plt.title("Percentage of diseased female patients")
# Out:
# Text(0.5, 1.0, 'Percentage of diseased female patients')

# %%
plt.figure(figsize=(3,3))
plt.pie(x=data[data["sex"]=="M"]["binaryclass"].value_counts(),
        labels=['Healthy','Diseased'],
        startangle = 90,
        colors=['indianred','peachpuff'],
        autopct='%.2f'
       )
plt.title("Percentage of diseased male patients")
# Out:
# Text(0.5, 1.0, 'Percentage of diseased male patients')

# %%
plt.figure(figsize=(3,3))
plt.pie(x=data[data["sick"]=="t"]["binaryclass"].value_counts(),
        labels=['Healthy','Diseased'],
        startangle = 90,
        colors=['indianred','peachpuff'],
        autopct='%.2f'
       )
plt.title("Percentage of diseased sick patients")
# Out:
# Text(0.5, 1.0, 'Percentage of diseased sick patients')

# %%
plt.figure(figsize=(3,3))
plt.pie(x=data[data["on_thyroxine"]=="t"]["binaryclass"].value_counts(),
        labels=['Healthy','Diseased'],
        startangle = 90,
        colors=['indianred','peachpuff'],
        autopct='%.2f'
       )
plt.title("Percentage of diseased patients on thyroxine")
# Out:
# Text(0.5, 1.0, 'Percentage of diseased patients on thyroxine')

# %%
plt.figure(figsize=(3,3))
plt.pie(x=data[data["on_antithyroid_medication"]=="t"]["binaryclass"].value_counts(),
        labels=['Healthy','Diseased'],
        startangle = 90,
        colors=['indianred','peachpuff'],
        autopct='%.2f'
       )
plt.title("Percentage of diseased patients on antithyroid medication")
# Out:
# Text(0.5, 1.0, 'Percentage of diseased patients on antithyroid medication')

# %%
plt.figure(figsize=(3,3))
plt.pie(x=data[data["thyroid_surgery"]=="t"]["binaryclass"].value_counts(),
        labels=['Healthy','Diseased'],
        startangle = 90,
        colors=['indianred','peachpuff'],
        autopct='%.2f'
       )
plt.title("Percentage of diseased patients who had thyroid surgery")
# Out:
# Text(0.5, 1.0, 'Percentage of diseased patients who had thyroid surgery')

# %%
plt.figure(figsize=(3,3))
plt.pie(x=data[data["i131_treatment"]=="t"]["binaryclass"].value_counts(),
        labels=['Healthy','Diseased'],
        startangle = 90,
        colors=['indianred','peachpuff'],
        autopct='%.2f'
       )
plt.title("Percentage of diseased patients who had i131 treatment")
# Out:
# Text(0.5, 1.0, 'Percentage of diseased patients who had i131 treatment')

# %%
plt.figure(figsize=(3,3))
plt.pie(x=data[data["tumor"]=="t"]["binaryclass"].value_counts(),
        labels=['Healthy','Diseased'],
        startangle = 90,
        colors=['indianred','peachpuff'],
        autopct='%.2f'
       )
plt.title("Percentage of diseased patients who have a tumor")
# Out:
# Text(0.5, 1.0, 'Percentage of diseased patients who have a tumor')

# %%
plt.figure(figsize=(3,3))
plt.pie(x=data[data["lithium"]=="t"]["binaryclass"].value_counts(),
        labels=['Healthy','Diseased'],
        startangle = 90,
        colors=['indianred','peachpuff'],
        autopct='%.2f'
       )
plt.title("Percentage of diseased patients who have lithium")
# Out:
# Text(0.5, 1.0, 'Percentage of diseased patients who have lithium')

# %%
plt.figure(figsize=(3,3))
sns.set_palette("Reds")
sns.boxplot(data=data, x="binaryclass", y="age", hue="binaryclass", dodge = False)
plt.legend([],[], frameon=False)

# %%
plt.figure(figsize=(3,3))
sns.set_palette("Reds")
sns.boxplot(data=data, x="binaryclass", y="t3", hue="binaryclass", dodge = False)
plt.legend([],[], frameon=False)

# %%
plt.figure(figsize=(3,3))
sns.set_palette("Reds")
sns.boxplot(data=data, x="binaryclass", y="tt4", hue="binaryclass", dodge = False)
plt.legend([],[], frameon=False)

# %%
plt.figure(figsize=(3,3))
sns.set_palette("Reds")
sns.boxplot(data=data, x="binaryclass", y="t4u", hue="binaryclass", dodge = False)
plt.legend([],[], frameon=False)

# %%
plt.figure(figsize=(3,3))
sns.set_palette("Reds")
sns.boxplot(data=data, x="binaryclass", y="fti", hue="binaryclass", dodge = False)
plt.legend([],[], frameon=False)

# %%
plt.figure(figsize=(3,3))
sns.set_palette("Reds")
sns.boxplot(data=data, x="binaryclass", y="tsh", hue="binaryclass", dodge = False)
plt.legend([],[], frameon=False)

# %%
data[data["binaryclass"] == "Healthy"].describe()
# Out:
#                age          tsh           t3          tt4          t4u  \
# count  3418.000000  3418.000000  3418.000000  3418.000000  3418.000000
# mean     51.771796     1.849781     2.049661   111.026624     0.992131
# std      18.999823     4.528439     0.733442    33.172030     0.187470
# min       1.000000     0.005000     0.050000    19.000000     0.250000
# 25%      36.000000     0.500000     1.700000    91.000000     0.890000
# 50%      54.000000     1.400000     2.000000   104.000000     0.980000
# 75%      67.000000     2.100000     2.300000   125.000000     1.070000
# max      94.000000   145.000000    10.600000   430.000000     2.320000
#
#                fti
# count  3418.000000
# mean    113.064365
# std      29.730178
# min      17.000000
# 25%      96.000000
# 50%     107.000000
# 75%     124.000000
# max     395.000000
